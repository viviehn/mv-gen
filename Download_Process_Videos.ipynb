# %%
from split_vids import *
#from make_csv import *
import csv
import os
import sys
from datetime import datetime
import sys
import tensorflow as tf
sys.path.insert(0, '/home/vivien/Classwork/cs182/mv-gen/models/research/audioset')

# %load_ext autoreload
# %autoreload 2

# %%
playlist_url = "https://www.youtube.com/playlist?list=PL9tY0BWXOZFubH8RSGxdBDwhf7g4C60Vy"
download_dir =  "downloaded_vids"

# %%
# Run youtube-dl command to download playlist

# !youtube-dl -i -f mp4 -o '{download_dir}/%(title)s.%(ext)s' {playlist_url}
# Out:
# [youtube:playlist] PL9tY0BWXOZFubH8RSGxdBDwhf7g4C60Vy: Downloading webpage
# [download] Downloading playlist: Incoming EDM
# [youtube:playlist] playlist Incoming EDM: Downloading 100 videos
# [download] Downloading video 1 of 100
# [youtube] ZdgU3b2cqpo: Downloading webpage
# [youtube] ZdgU3b2cqpo: Downloading video info webpage
# [download] Destination: downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4
# [download] 100% of 14.84MiB in 00:0453MiB/s ETA 00:0084
# [download] Downloading video 2 of 100
# [youtube] XRgEsP1HMIQ: Downloading webpage
# [youtube] XRgEsP1HMIQ: Downloading video info webpage
# [download] Destination: downloaded_vids/Semitoo - Heaven (Official Music Video).mp4
# [download] 100% of 10.03MiB in 00:0194MiB/s ETA 00:004
# [download] Downloading video 3 of 100
# [youtube] u-odU4ytN0g: Downloading webpage
# [youtube] u-odU4ytN0g: Downloading video info webpage
# [youtube] u-odU4ytN0g: Downloading MPD manifest
# [download] Destination: downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4
# [download] 100% of 15.46MiB in 00:0209MiB/s ETA 00:007
# [download] Downloading video 4 of 100
# [youtube] 9vjzRgt5cP8: Downloading webpage
# [youtube] 9vjzRgt5cP8: Downloading video info webpage
# [download] Destination: downloaded_vids/DJ BEDA - My Time ft. Karol Diac.mp4
# [download] 100% of 17.96MiB in 00:0475MiB/s ETA 00:0018
# [download] Downloading video 5 of 100
# [youtube] HPTBaPZz27M: Downloading webpage
# [youtube] HPTBaPZz27M: Downloading video info webpage
# [download] Destination: downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4
# [download] 100% of 14.77MiB in 00:0579MiB/s ETA 00:005
# [download] Downloading video 6 of 100
# [youtube] P0y5GlZsUuA: Downloading webpage
# [youtube] P0y5GlZsUuA: Downloading video info webpage
# ^C
#
# ERROR: Interrupted by user

# %%
data_csv = "video_data.csv"
vid_dir = "split_vids_dir"
start_at = 0  # edit this value
global_counter = start_at
split_length = 10  # seconds



output_dir = os.getcwd() + '/' + vid_dir
input_dir = os.getcwd() + '/' + download_dir + '/'

# make vid_dir if not already exists
# !mkdir {output_dir}

downloaded_vids = [f for f in os.listdir(input_dir) if os.path.isfile(input_dir + f)]

with open(data_csv, mode="w") as file:
    data_writer = csv.writer(file)
    for vid in downloaded_vids:
        print(vid)
        vid_abs_path = input_dir + vid
        num_vids = split_video(vid_abs_path, output_dir, global_counter, split_length)
        
        split_vid_title = vid.split('-')
        title = split_vid_title[1].split('.')[0]
        artist = split_vid_title[0]
        
        data_writer.writerow([title, artist, global_counter, global_counter + num_vids - 1])
        
        global_counter += num_vids
        
# now process_dir should contain all the split videos
# create csv for youtube-8m
# Out:
# KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4
# About to run: ffprobe -v error -show_entries format=duration -of default=noprint_wrappers=1:nokey=1 -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4
# Video length in seconds: 215
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 0 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/0.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 10 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/1.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 20 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/2.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 30 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/3.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 40 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/4.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 50 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/5.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 60 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/6.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 70 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/7.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 80 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/8.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 90 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/9.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 100 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/10.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 110 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/11.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 120 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/12.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 130 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/13.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 140 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/14.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 150 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/15.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 160 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/16.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 170 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/17.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 180 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/18.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 190 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/19.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 200 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/20.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/KATO - Never Let U Go ft. Snoop Dogg, Brandon Beal.mp4 -vcodec copy -acodec copy -ss 210 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/21.mp4
# Semitoo - Heaven (Official Music Video).mp4
# About to run: ffprobe -v error -show_entries format=duration -of default=noprint_wrappers=1:nokey=1 -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4
# Video length in seconds: 176
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 0 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/22.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 10 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/23.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 20 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/24.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 30 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/25.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 40 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/26.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 50 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/27.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 60 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/28.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 70 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/29.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 80 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/30.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 90 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/31.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 100 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/32.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 110 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/33.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 120 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/34.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 130 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/35.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Semitoo - Heaven (Official Music Video).mp4 -vcodec copy -acodec copy -ss 140 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir
-t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/62.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 20 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/63.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 30 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/64.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 40 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/65.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 50 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/66.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 60 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/67.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 70 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/68.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 80 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/69.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 90 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/70.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 100 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/71.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 110 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/72.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 120 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/73.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 130 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/74.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 140 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/75.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 150 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/76.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 160 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/77.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 170 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/78.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 180 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/79.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 190 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/80.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Salón Acapulco - Jamba Jamba ft. Rachel West.mp4 -vcodec copy -acodec copy -ss 200 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/81.mp4
# Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4
# About to run: ffprobe -v error -show_entries format=duration -of default=noprint_wrappers=1:nokey=1 -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4
# Video length in seconds: 216
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 0 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/82.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 10 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/83.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 20 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/84.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 30 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/85.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 40 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/86.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 50 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/87.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 60 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/88.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 70 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/89.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 80 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/90.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 90 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/91.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 100 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/92.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 110 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/93.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 120 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/94.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 130 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/95.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 140 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/96.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 150 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/97.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 160 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/98.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 170 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/99.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 180 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/100.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 190 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/101.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 200 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/102.mp4
# About to run: ffmpeg -i /home/vivien/Classwork/cs182/mv-gen/downloaded_vids/Gesaffelstein & Pharrell Williams - Blast Off (Official Video).mp4 -vcodec copy -acodec copy -ss 210 -t 10 /home/vivien/Classwork/cs182/mv-gen/split_vids_dir/103.mp4

# %%
audio_dir = "split_audio_dir/"
# !mkdir -p {audio_dir}

split_vids_dir = output_dir + '/'
split_vids = [f for f in os.listdir(split_vids_dir) if os.path.isfile(split_vids_dir + f)]

for vid in split_vids:
    vid_abs_path = split_vids_dir + vid
    audio_path = audio_dir + vid.split('.')[0]
    # !ffmpeg -i {vid_abs_path} {audio_path}.wav
# Out:
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/72.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 523 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 532 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/72.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.11e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.007007, bitrate: 502 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 469 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.16e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/87.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 668 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 685 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/87.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.11e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/32.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 476 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x252 [SAR 1:1 DAR 160:63], 374 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/32.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.01 bitrate=1410.1kbits/s speed=1.11e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/17.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 632 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 581 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/17.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.12e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/84.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 668 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 585 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/84.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.12e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/30.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 448 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x252 [SAR 1:1 DAR 160:63], 364 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/30.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.12e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/25.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 395 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x252 [SAR 1:1 DAR 160:63], 321 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/25.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.16e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/76.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 676 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 630 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/76.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.08e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/100.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000998, bitrate: 377 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 304 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/100.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.16e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/81.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 362 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 327 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/81.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.2e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/77.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.008005, bitrate: 591 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 562 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/77.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.16e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/63.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 456 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 416 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/63.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.12e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/12.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 505 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 458 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/12.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.1e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 539 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 444 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.14e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 527 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 448 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.14e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.007007, bitrate: 467 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 367 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/65.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.15e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/45.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.015011, bitrate: 637 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 630 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/45.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.16e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/57.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 689 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 616 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/57.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.12e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/14.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 580 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 552 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/14.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.15e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/43.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 683 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 649 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/43.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1724kB time=00:00:10.00 bitrate=1411.3kbits/s speed=1.21e+03x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004418%
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/vivien/Classwork/cs182/mv-gen/split_vids_dir/20.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:09.99, start: 0.016009, bitrate: 660 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x274 [SAR 1:1 DAR 320:137], 608 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'split_audio_dir/20.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 pcm_s16le
# size=    1720kB time=00:00:09.98 bitrate=1411.3kbits/s speed=1.17e+03x
# video:0kB audio:1720kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004429%

# %%
# create csv for youtube-8m extractor
import tensorflow

working_dir = split_vids_dir

files = [f for f in os.listdir(working_dir) if os.path.isfile(working_dir + f)]

with open(working_dir +'videos_list.csv', mode='w') as videos:
    video_writer = csv.writer(videos)
    for f in files:
        abs_path = working_dir + f
        video_writer.writerow([abs_path, "14"])
# Out:
# 2019-05-01 00:28:00.662946: W tensorflow/core/framework/op_def_util.cc:355] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# 2019-05-01 00:28:00.757615: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-01 00:28:00.845901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-01 00:28:00.846582: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x172ca60 executing computations on platform CUDA. Devices:
# 2019-05-01 00:28:00.846609: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1070, Compute Capability 6.1
# 2019-05-01 00:28:00.869617: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3504000000 Hz
# 2019-05-01 00:28:00.869805: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1df0210 executing computations on platform Host. Devices:
# 2019-05-01 00:28:00.869817: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-01 00:28:00.870086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.835
# pciBusID: 0000:01:00.0
# totalMemory: 7.93GiB freeMemory: 7.56GiB
# 2019-05-01 00:28:00.870098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-05-01 00:28:00.871075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-01 00:28:00.871099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-05-01 00:28:00.871111: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-05-01 00:28:00.871417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7355 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Traceback (most recent call last):
#   File "youtube-8m/feature_extractor/extract_tfrecords_main.py", line 201, in <module>
#     app.run(main)
#   File "/home/vivien/.local/lib/python3.6/site-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "youtube-8m/feature_extractor/extract_tfrecords_main.py", line 146, in main
#     for video_file, labels in csv.reader(open(FLAGS.input_videos_csv)):
# FileNotFoundError: [Errno 2] No such file or directory: 'videos_list.csv'

# %%
# run youtube-8m feature extractor on videos in vid_dir
current_time = str(datetime.now().timestamp())
# !python3 youtube-8m/feature_extractor/extract_tfrecords_main.py --input_videos_csv videos_list.csv --output_tfrecords_file {current_time}.tfrecord
#!mv {split_vids_dir} done_vids/{current_time}
# Out:
# 2019-05-01 00:29:22.101773: W tensorflow/core/framework/op_def_util.cc:355] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# 2019-05-01 00:29:22.196939: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-05-01 00:29:22.261823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-01 00:29:22.262355: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2b64a60 executing computations on platform CUDA. Devices:
# 2019-05-01 00:29:22.262384: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce GTX 1070, Compute Capability 6.1
# 2019-05-01 00:29:22.281695: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3504000000 Hz
# 2019-05-01 00:29:22.282149: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3228210 executing computations on platform Host. Devices:
# 2019-05-01 00:29:22.282191: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-01 00:29:22.282866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.835
# pciBusID: 0000:01:00.0
# totalMemory: 7.93GiB freeMemory: 7.56GiB
# 2019-05-01 00:29:22.282902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-05-01 00:29:22.284325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-01 00:29:22.284350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-05-01 00:29:22.284362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-05-01 00:29:22.284938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7355 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-05-01 00:29:22.654808: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# Successfully encoded 104 out of 104 videos

# %%
# run audioset feature extractor on wav files in audio_dir
from vggish_input import wavfile_to_examples
from vggish_postprocess import Postprocessor

import vggish_slim
import vggish_params
import vggish_input

def CreateVGGishNetwork(hop_size=0.96):   # Hop size is in seconds.
    """Define VGGish model, load the checkpoint, and return a dictionary that points
    to the different tensors defined by the model.
    """
    vggish_slim.define_vggish_slim()
    checkpoint_path = '/home/vivien/Classwork/cs182/mv-gen/models/research/audioset/vggish_model.ckpt'
    vggish_params.EXAMPLE_HOP_SECONDS = hop_size

    vggish_slim.load_vggish_slim_checkpoint(sess, checkpoint_path)

    features_tensor = sess.graph.get_tensor_by_name(
      vggish_params.INPUT_TENSOR_NAME)
    embedding_tensor = sess.graph.get_tensor_by_name(
      vggish_params.OUTPUT_TENSOR_NAME)

    layers = {'conv1': 'vggish/conv1/Relu',
            'pool1': 'vggish/pool1/MaxPool',
            'conv2': 'vggish/conv2/Relu',
            'pool2': 'vggish/pool2/MaxPool',
            'conv3': 'vggish/conv3/conv3_2/Relu',
            'pool3': 'vggish/pool3/MaxPool',
            'conv4': 'vggish/conv4/conv4_2/Relu',
            'pool4': 'vggish/pool4/MaxPool',
            'fc1': 'vggish/fc1/fc1_2/Relu',
            'fc2': 'vggish/fc2/Relu',
            'embedding': 'vggish/embedding',
            'features': 'vggish/input_features',
         }
    g = tf.get_default_graph()
    for k in layers:
        layers[k] = g.get_tensor_by_name( layers[k] + ':0')

    return {'features': features_tensor,
          'embedding': embedding_tensor,
          'layers': layers,
         }
tf.reset_default_graph()

sess = tf.Session()
vgg = CreateVGGishNetwork(0.01)


audio_dir = "split_audio_dir/"
x = audio_dir + "2.wav"
input_batch = wavfile_to_examples(x)

[embedding_batch] = sess.run([vgg['embedding']],
                           feed_dict={vgg['features']: input_batch})

# Postprocess the results to produce whitened quantized embeddings.
pca_params_path = '/home/vivien/Classwork/cs182/mv-gen/models/research/audioset/vggish_pca_params.npz'

pproc = Postprocessor(pca_params_path)
postprocessed_batch = pproc.postprocess(embedding_batch)
# print('Postprocessed VGGish embedding: ', postprocessed_batch[0])
embedding_batch.shape
# Out:
# INFO:tensorflow:Restoring parameters from /home/vivien/Classwork/cs182/mv-gen/models/research/audioset/vggish_model.ckpt
# (901, 128)

# %%
# Out:
# (901, 128)

# %%
pca_params_path = '/home/vivien/Classwork/cs182/mv-gen/models/research/audioset/vggish_pca_params.npz'
checkpoint_path = '/home/vivien/Classwork/cs182/mv-gen/models/research/audioset/vggish_model.ckpt'


!(python3 models/research/audioset/vggish_inference_demo.py --wav_file split_audio_dir/1.wav \
                                    --tfrecord_file audio_out.tfrecord \
                                    --checkpoint {checkpoint_path} \
                                    --pca_params {pca_params_path})
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# [[[1.70349494 1.48106389 1.15174383 ... 0.85385017 1.44252344 0.09323096]
#   [1.76976303 1.80646644 2.02665898 ... 0.95017149 1.48477691 0.32336512]
#   [1.6493776  1.59893543 1.65108931 ... 1.16305429 1.22618255 0.57683805]
#   ...
#   [3.22278201 2.6045761  2.02046286 ... 1.59729291 1.74721816 1.88439326]
#   [1.95687102 0.33143174 1.57555659 ... 1.52876216 1.25824186 1.78787724]
#   [2.4959316  2.42462478 2.42278571 ... 1.07401057 1.39582225 1.58309436]]
#
#  [[1.99865833 1.64408925 2.56988215 ... 0.99733917 1.1969515  1.16023204]
